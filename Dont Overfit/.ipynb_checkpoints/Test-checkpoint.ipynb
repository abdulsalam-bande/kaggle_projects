# %%
import pandas as pd

# %%
data = pd.read_csv("train.csv")
print(data.iloc[23])
# Out:
# id        23.000
# target     1.000
# 0          0.635
# 1         -0.468
# 2          1.333
#            ...
# 295        0.130
# 296        0.466
# 297        0.027
# 298       -0.437
# 299       -0.087
# Name: 23, Length: 302, dtype: float64

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
class  Training_DataSet(Dataset):
    def __init__(self,csv_file,root_dir,transform):
        self.data = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self,idx):
        features = self.data.iloc[idx]  
        target = features['target'] #yoyoy
        features = features.drop(labels='id',axis=0)
        features = features.drop(labels='target',axis=0)
        
        sample = {"features":features,"target":target}
        
        if self.transform:
            sample = self.transform(sample)
            
        return sample

# %%
class to_tensor_training(object):
    def __call__(self,sample):
        features , target = sample['features'],sample['target']
        features = np.array([features])
        features = features.astype('float32')
        features = torch.from_numpy(features)
        features = features.float()
        target = np.array([target])
        target = torch.from_numpy(target)
        target = target.long()
        
        return {"features":features,"target":target}

# %%
transformed_dataset = Training_DataSet(csv_file="train.csv",
                                       root_dir="/Users/abdulsalamyazid/Desktop/Projects/Kaggle",
                                       transform = to_tensor_training())

# %%
for i in range(len(transformed_dataset)):
    sample = transformed_dataset[i]

    print(i, sample['features'].size(),sample['target'])

    if i == 3:
        break
# Out:
# 0 torch.Size([1, 300]) tensor([1])
# 1 torch.Size([1, 300]) tensor([0])
# 2 torch.Size([1, 300]) tensor([1])
# 3 torch.Size([1, 300]) tensor([1])

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.fc1 = nn.Linear(300,512)
        #self.fc2 = nn.Linear(128,256)
        #self.fc3 = nn.Linear(256,512)
        #self.fc4 = nn.Linear(512,64)
        self.fc5 = nn.Linear(512,2)
        
    def forward(self,x):
        #drouput_activation1 = nn.Dropout(p=0.3)
        x = F.sigmoid(self.fc1(x))
        #x = F.relu(self.fc2(x))
        #x = F.relu(self.fc3(x))
       # x = F.relu(self.fc4(x))
        x = self.fc5(x)
        return x

# %%
net = Net()

# %%
trainloader = torch.utils.data.DataLoader(transformed_dataset,batch_size=4, shuffle=True,num_workers=2)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
loss_array = []
correct = 0
total = 0

accuracy_array = []
for epoch in range(11):
    running_loss = 0
    for i , data in enumerate(trainloader,0):
        features , target = data['features'],data['target']
        target = target.squeeze()
        optimizer.zero_grad()
        outputs = net(features)
        outputs = outputs.squeeze()
        _, predictions = torch.max(outputs,1)
        total += target.size(0)
        correct += (predictions == target).sum().item()
        print(outputs.shape)
        print(target.shape)
        loss = criterion(outputs,target)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        
        
    loss_array.append(running_loss / len(trainloader))
    
    print("Epoch: {}/ 10.. ".format(epoch+1),
              "Training Loss: {:.3f}.. ".format(running_loss/len(trainloader)))
    print("Accuracy  %d %%" %(100*correct/total))
    correct = 0
    total = 0
print("Finished training")
# Out:
# /Users/abdulsalamyazid/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([2, 2])
# torch.Size([2])
# Epoch: 1/ 10..  Training Loss: 0.707..
# Accuracy  57 %
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([2, 2])
# torch.Size([2])
# Epoch: 2/ 10..  Training Loss: 0.672..
# Accuracy  64 %
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# torch.Size([4, 2])
# torch.Size([4])
# Traceback (most recent call last):
#   File "/Users/abdulsalamyazid/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/Users/abdulsalamyazid/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/Users/abdulsalamyazid/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/Users/abdulsalamyazid/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-cb26ea9a3190> in <module>
#      18         print(target.shape)
#      19         loss = criterion(outputs,target)
# ---> 20         loss.backward()
#      21         optimizer.step()
#      22         running_loss += loss.item()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
### TESTING

# %%
class  Testing_DataSet(Dataset):
    def __init__(self,csv_file,root_dir,transform):
        self.data = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self,idx):
        features = self.data.iloc[idx]  
        idi = features['id']
        features = features.drop(labels='id',axis=0)

        
        sample = {"features":features,"idi":idi}
        
        if self.transform:
            sample = self.transform(sample)
            
        return sample

# %%
class to_tensor_testing(object):
    def __call__(self,sample):
        features , idi = sample['features'],sample['idi']
        features = np.array([features])
        features = features.astype('float32')
        features = torch.from_numpy(features)
        features = features.float()
        
        return {"features":features,"idi":idi}

# %%
transformed_dataset_testing = Testing_DataSet(csv_file="test.csv",
                                       root_dir="/Users/abdulsalamyazid/Desktop/Projects/Kaggle",
                                       transform = to_tensor_testing())

# %%
for i in range(len(transformed_dataset_testing)):
    sample = transformed_dataset_testing[i]

    print(i, type(sample['features'].numpy()),type(sample['idi']))

    if i == 3:
        break
# Out:
# 0 <class 'numpy.ndarray'> <class 'numpy.float64'>
# 1 <class 'numpy.ndarray'> <class 'numpy.float64'>
# 2 <class 'numpy.ndarray'> <class 'numpy.float64'>
# 3 <class 'numpy.ndarray'> <class 'numpy.float64'>

# %%
data = {'id':[],
        'target':[]}
df = pd.DataFrame(data)
df = df[['id','target']]
df.head()
df = df.append({'id': 32, 'target':23}, ignore_index=True)
df.head()
# Out:
#      id  target
# 0  32.0    23.0

# %%
mynum = 233
target = 1
for x in range(10):
    df = df.append({"id":mynum,"target":target },ignore_index=True)
    
df
# Out:
#        id  target
# 0    32.0    23.0
# 1   233.0     1.0
# 2   233.0     1.0
# 3   233.0     1.0
# 4   233.0     1.0
# 5   233.0     1.0
# 6   233.0     1.0
# 7   233.0     1.0
# 8   233.0     1.0
# 9   233.0     1.0
# 10  233.0     1.0

# %%
my_data = {'id':[],
        'target':[]}
df = pd.DataFrame(my_data)
df = df[['id','target']]
df.head()
# Out:
# Empty DataFrame
# Columns: [id, target]
# Index: []

# %%
testloader = torch.utils.data.DataLoader(transformed_dataset_testing, batch_size=1,shuffle=False,num_workers=0)

with torch.no_grad():
    for i ,data in enumerate(testloader):
        features , idi = data['features'],data['idi']
        features = features.squeeze(0)
        output = net(features)
        _, predictions = torch.max(output,1)
        df = df.append({"id":int(int(idi)),"target":int(int(predictions))},ignore_index=True)

# %%
df['id'] = df['id'].astype(int)
df['target'] = df['target'].astype(int)
df.to_csv("submission.csv",header = True,index= False)
df.head()
# Out:
#     id  target
# 0  250       1
# 1  251       1
# 2  252       1
# 3  253       1
# 4  254       1

# %%
a = torch.tensor([1])
print((a.dtype))
# Out:
# torch.int64

# %%
print(int(predictions))
# Out:
# 1

# %%
ar = predictions.numpy()
ar
# Out:
# array([1])

# %%
df['id'] = df['id'].astype(int64)
df['targer'] = df['target'].astype(int64)

# %%
df1 = pd.read_csv("sample_submission.csv")
a = df1.iloc[1]

# %%
print(a['target'].dtype)
# Out:
# int64
